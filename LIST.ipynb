# %% [markdown]
# <a href="https://colab.research.google.com/github/adityamishra24/SD_ADITYAMISHRA_0024/blob/main/LIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
X=4

# %%
X
# Out:
# 4

# %%
NUMS=[1,2,3,4]

# %%
type(NUMS)
# Out:
# list

# %%
NUMS[0]
# Out:
# 1

# %%
NUMS[1]
# Out:
# 2

# %%
NUMS[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_2485/2886041085.py in <cell line: 0>()
# ----> 1 NUMS[4]
#
# IndexError: list index out of range

# %%
N=[1,2,3,4,"WE","SFD","EWEW",'A', "True", False ,5+9j]

# %%
type(N[7])
# Out:
# str

# %%
N[0:12:2]
# Out:
# [1, 3, 'WE', 'EWEW', True, (5+9j)]

# %%
N[10].real
# Out:
# 5.0

# %%
N[0:5:4]
# Out:
# [1, 'WE']

# %%
N[::-1]
# Out:
# [(5+9j), False, True, 'A', 'EWEW', 'SFD', 'WE', 4, 3, 2, 1]

# %%
N[-1:-5:-2]
# Out:
# [(5+9j), True]

# %%
N[1:6:-2]
# Out:
# []

# %%
N[0:12:10]
# Out:
# [1, (5+9j)]

# %%
N.append(1)

# %%
N[11]
# Out:
# 1

# %%
s="gcjchjsmksdvjkdgfjgidhijudghfjghjd"

# %%
N+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_937/2236157763.py in <cell line: 0>()
# ----> 1 N+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(s)+N
# Out:
# ['g',
#  'c',
#  'j',
#  'c',
#  'h',
#  'j',
#  's',
#  'm',
#  'k',
#  's',
#  'd',
#  'v',
#  'j',
#  'k',
#  'd',
#  'g',
#  'f',
#  'j',
#  'g',
#  'i',
#  'd',
#  'h',
#  'i',
#  'j',
#  'u',
#  'd',
#  'g',
#  'h',
#  'f',
#  'j',
#  'g',
#  'h',
#  'j',
#  'd',
#  1,
#  2,
#  3,
#  4,
#  'WE',
#  'SFD',
#  'EWEW',
#  'A',
#  True,
#  False,
#  (5+9j),
#  1,
#  1]

# %%
l=[1]

# %%
l.append(2)

# %%
l
# Out:
# [1, 2]

# %%
l.pop(1)
# Out:
# 2

# %%
l
# Out:
# [1]

# %%
N[4][1]
# Out:
# 'E'

# %%
N[5][0:2]
# Out:
# 'SF'

# %%
N[8][0:2]
# Out:
# 'Tr'

# %%
str(N[9])[0:2]
# Out:
# 'Fa'

# %%
N.insert(2,78)

# %%
l
# Out:
# [1]

# %%
N
# Out:
# [1, 2, 78, 78, 3, 4, 'WE', 'SFD', 'EWEW', 'A', 'True', False, (5+9j)]

# %%
N.remove(78)

# %%
N
# Out:
# [1, 78, 3, 4, 'WE', 'SFD', 'EWEW', 'A', 'True', False, (5+9j)]

# %%
N.insert(5,9)

# %%
N
# Out:
# [1, 78, 3, 4, 'WE', 9, 'SFD', 'EWEW', 'A', 'True', False, (5+9j)]

# %%
name=input("enter your name ")
# Out:
# enter your name adity

# %%
name
# Out:
# 'adity'

# %%
print("Name:",name)
# Out:
# Name: adity

# %%
x="10"

# %%
int(x)
# Out:
# 10

# %%
float(x)
# Out:
# 10.0

# %%
list(x)
# Out:
# ['1', '0']

# %%
tuple(x)
# Out:
# ('1', '0')

# %%
set(x)
# Out:
# {'0', '1'}

# %%
x=[1,2,3,4]

# %%
y=set(x)

# %%
print(y)
# Out:
# {1, 2, 3, 4}

# %%
l=[1,345,45,"sudh", True,5+7j,345.456]

# %%
len(l)
# Out:
# 7

# %%
l[(len(l)-2)]
# Out:
# (5+7j)

# %%
s="hjgjhgjhikojok"

# %%
str(l[4])[0:2]
# Out:
# 'Tr'

# %%
l1=[8,9,0,8]

# %%
a=l+l1

# %%
a
# Out:
# [345, 45, 'sudh', True, (5+7j), 8, 9, 0, 8]

# %%
s={1,2,4,3,4}

# %%
l2=[1,2,3,4,"hghghg",[1,2,3,5,"ggghh",9],899,00,99]

# %%
l2[4][0:3]
# Out:
# [1, 2, 3]

# %%
l2[4][4][0:2]
# Out:
# 'gg'

# %%
l2.append(s)

# %%
l2.extend(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1942/4251890973.py in <cell line: 0>()
# ----> 1 l2.extend(4)
#
# TypeError: 'int' object is not iterable

# %%
l2.extend("aditya")

# %%
l2
# Out:
# [1,
#  2,
#  3,
#  4,
#  'hghghg',
#  [1, 2, 3, 5, 'ggghh', 9],
#  899,
#  0,
#  99,
#  'a',
#  'd',
#  'i',
#  't',
#  'y',
#  'a']

# %%
l*3
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456,
#  1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456,
#  1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456]

# %%
l2.insert(3,"jjuh")

# %%
l2
# Out:
# [1,
#  2,
#  3,
#  'jjuh',
#  4,
#  'hghghg',
#  [1, 2, 3, 5, 'ggghh', 9],
#  899,
#  0,
#  99,
#  'a',
#  'd',
#  'i',
#  't',
#  'y',
#  'a']

# %%
l.pop()
# Out:
# 345.456

# %%
l.remove(1)

# %%
l
# Out:
# [345, 45, 'sudh', True, (5+7j)]

# %%
a.remove(8)

# %%
a
# Out:
# [345, 45, 'sudh', True, (5+7j), 9, 0, 8]

# %%
a.reverse()

# %%
a
# Out:
# [8, 0, 9, (5+7j), True, 'sudh', 45, 345]

# %%
l3=[5,56,34,89]

# %%
l3.sort()

# %%
l3
# Out:
# [5, 34, 56, 89]

# %%
l3.index(56)
# Out:
# 2

# %%
a.replace('s','a')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1942/2588283635.py in <cell line: 0>()
# ----> 1 a.replace('s','a')
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
s="sudha"

# %%
s.replace('s','a')
# Out:
# 'audha'

# %%
         s.replace('a','g')
# Out:
# 'sudhg'

# %%
t=(1,2,3,4,5)

# %%
type(t)
# Out:
# tuple

# %%
s3={67,89,890,6677,"hggj",89,"kj"}

# %%
s3
# Out:
# {6677, 67, 89, 890, 'hggj', 'kj'}

# %%
s3.remove(67)

# %%
s3
# Out:
# {6677, 89, 890, 'hggj', 'kj'}

# %%
dict={'a':1,'g':4}

# %%
dict
# Out:
# {'a': 1, 'g': 4}

# %%
type(dict)
# Out:
# dict

# %%
dict['a']
# Out:
# 1

# %%
j
name=(input("enter name"))
course=(input("enter course"))
rollno=int(input("enter the roll no "))
branch=(input("enter the  branch"))
s1=int(input("marks of fme"))
s2=int(input("marks of m1"))
s3=int(input("marks of EC"))
s4=int(input("marks of SOFT SKILLS"))
s5=int(input("marks of CHEMISTRY"))
PERCENTAGE=((s1+s2+s3+s4+s5)/500)*100
print(PERCENTAGE)
# Out:
# enter nameaditya
# enter courseh
# enter the roll no h
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1942/967869359.py in <cell line: 0>()
#       1 name=(input("enter name"))
#       2 course=(input("enter course"))
# ----> 3 rollno=int(input("enter the roll no "))
#       4 branch=(input("enter the  branch"))
#       5 s1=int(input("marks of fme"))
#
# ValueError: invalid literal for int() with base 10: 'h'

# %%
name=(input("enter name"))
course=(input("enter course"))
rollno=int(input("enter the roll no "))
branch=(input("enter the  branch"))
s1=int(input("marks of fme"))
s2=int(input("marks of m1"))
s3=int(input("marks of EC"))

s4=int(input("marks of SOFT SKILLS"
# Out:
#   File "/tmp/ipykernel_1942/3696448249.py", line 9
#     s4=int(input("marks of SOFT SKILLS"
#                                        ^
# SyntaxError: incomplete input

# %%
name=(input("enter name"))
course=(input("enter course"))
rollno=int(input("enter the roll no "))
branch=(input("enter the  branch"))
s1=int(input("marks of fme"))
s2=int(input("marks of m1"))
s3=int(input("marks of EC"))
s4=int(input("marks of SOFT SKILLS"))
s5=int(input("marks of CHEMISTRY"))
PERCENTAGE=((s1+s2+s3+s4+s5)/500)*100
print(PERCENTAGE)
for i in range(5):
  choice=(input("your subject coice"))
  int(choice)
  if choice>=80:
    print("a")
  elif choice>=60 and choice<80:
    print("b")
  elif choice>=40 and choice<60:
    print("c")
  else:
    print("fail")

# %%
l=int(input)
